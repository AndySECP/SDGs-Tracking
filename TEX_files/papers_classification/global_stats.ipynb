# %% [markdown]
# ## Global Statistics

# %%
import warnings
warnings.filterwarnings('ignore')
from classification import *
from processing import *

# %%
#get_global_stats(direct='Papers')

# %%
dat
# Out:
# {'SDG Goal 1': 422423,
#  'Main 1': 18,
#  'SDG Goal 2': 79942,
#  'Main 2': 0,
#  'SDG Goal 3': 3728099,
#  'Main 3': 63,
#  'SDG Goal 4': 12490078,
#  'Main 4': 808,
#  'SDG Goal 5': 2193607,
#  'Main 5': 36,
#  'SDG Goal 6': 2075972,
#  'Main 6': 16,
#  'SDG Goal 7': 15711785,
#  'Main 7': 668,
#  'SDG Goal 8': 2674289,
#  'Main 8': 23,
#  'SDG Goal 9': 4720594,
#  'Main 9': 55,
#  'SDG Goal 10': 7089865,
#  'Main 10': 186,
#  'SDG Goal 11': 2370183,
#  'Main 11': 17,
#  'SDG Goal 12': 153529,
#  'Main 12': 0,
#  'SDG Goal 13': 2952614,
#  'Main 13': 1,
#  'SDG Goal 14': 1398778,
#  'Main 14': 5,
#  'SDG Goal 15': 4319392,
#  'Main 15': 75,
#  'SDG Goal 16': 2699976,
#  'Main 16': 11,
#  'SDG Goal 17': 6856451,
#  'Main 17': 89}

# %%
display_global_stats(keywords_occ = True, main_sdg = True, display_df = True)
